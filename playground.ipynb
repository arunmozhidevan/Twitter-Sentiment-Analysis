# %% [markdown]
# Installing required libraries

# %%
# %pip install tweepy TextBlob
# Out:
# Requirement already satisfied: tweepy in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (4.12.1)
# Requirement already satisfied: TextBlob in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.17.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tweepy) (2.28.2)
# Requirement already satisfied: nltk>=3.1 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from TextBlob) (3.8.1)
# Requirement already satisfied: joblib in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk>=3.1->TextBlob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk>=3.1->TextBlob) (2022.10.31)
# Requirement already satisfied: click in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk>=3.1->TextBlob) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk>=3.1->TextBlob) (4.64.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.27.0->tweepy) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.27.0->tweepy) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\amd\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click->nltk>=3.1->TextBlob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the 'C:\Users\AMD\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import tweepy # Tweepy - Python library for accessing the Twitter API.
import re # Regular Expression Python module
from textblob import TextBlob # TextBlob - Python library for processing textual data
import os
from dotenv import load_dotenv # load the .env file
load_dotenv()
import pandas as pd

# %%
twitterApiKey = os.getenv("API_key")
twitterApiSecret = os.getenv("API_secret_key")
twitterApiAccessToken = os.getenv("Access_token")
twitterApiAccessTokenSecret = os.getenv("Access_token_secret")

# %%
auth = tweepy.OAuthHandler(twitterApiKey,twitterApiSecret)
auth.set_access_token(twitterApiAccessToken,twitterApiAccessTokenSecret)
twitterApi = tweepy.API(auth, wait_on_rate_limit = True)

# %%
def getTweets(twitterAccount, total_tweets):
    return tweepy.Cursor(twitterApi.user_timeline, 
                        screen_name=twitterAccount, 
                        count=None,
                        since_id=None,
                        max_id=None,
                        trim_user=True,
                        exclude_replies=True,
                        tweet_mode='extended'
                        ).items(total_tweets)

# %%
Account = "BillGates"
total_tweets = 100

# %%
# df = pd.DataFrame(data=[tweet.text for tweet in tweets(Account, total_tweets)], columns=['Tweet'])
# df

# %%
count = 0
for i in getTweets(Account, total_tweets):
    print(i._json, end='\n\n')
    count += 1
    if count:
        break
# Out:
# {'created_at': 'Sat Feb 18 01:26:40 +0000 2023', 'id': 1626755042454933505, 'id_str': '1626755042454933505', 'full_text': 'The world is facing multiple crises around energy, food and health. These threats are interconnected and require a joined-up response, prioritizing global cooperation and innovation. https://t.co/KcVdDV2jqC', 'truncated': False, 'display_text_range': [0, 206], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/KcVdDV2jqC', 'expanded_url': 'https://b-gat.es/3XEAalR', 'display_url': 'b-gat.es/3XEAalR', 'indices': [183, 206]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 50393960, 'id_str': '50393960'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 280, 'favorite_count': 1729, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}

# %%
api = tweepy.API(auth)
test_tweets = api.home_timeline()

# Looping through the tweets:
for tweet in test_tweets:
    print(tweet.text + "\n")
# Out:
# It won't be long until everyone who was so on board with this gender affirmation betrayal of children will deny eve… https://t.co/IOa6qXWI3F
#
# RT @theemozilla: New blog: Language Models vs. the SAT Reading Test! They score ~90%, and FLAN-T5 does as well as GPT-3.5! Finetuning even…
#
# Poisson summation formula https://t.co/IRiJBcXvRS
#
# நிலக்கரி ஊழல் புகார் - சத்தீஸ்கர் காங்கிரஸ் தலைவர்களின் வீடுகளில் அமலாக்கத் துறை அதிகாரிகள் சோதனை
#
# #Chattisgarh… https://t.co/Q0oEYEe46i
#
# Telltale shows off a bunch of new gameplay from its upcoming game based on The Expanse. https://t.co/K4stn1yYeD
#
# Whaaaa? https://t.co/XjcquJO3qP
#
# Incognito Mode isn't as private as some people believe.
#
# Avoid "fingerprinting" — where companies combine details… https://t.co/vjEOrXSzsW
#
# Driveclub, the racing game meant to to help usher in the PlayStation 4, ultimately crashed at the finish line, lead… https://t.co/pEinXfAieJ
#
# Chronic pain, such as arthritis, cancer or back pain, lasting for over three months, raises the risk of cognitive d… https://t.co/8AAFrfTu9y
#
# RT @realpython: 🐍🐋 Python Docker Tutorials — Docker is a containerization tool used for spinning up isolated, reproducible application envi…
#
# Becoming an ‘#AI Powerhouse’ Means Going All In. Read more: https://t.co/4PYJBZ7dAG
#
# சேலத்தில் வனவிலங்கை வேட்டையாட முயற்சி - நாட்டு துப்பாக்கியுடன் இருவரை கைதுசெய்த வனத்துறை
#
# #salem #forest #Hunting
#
# https://t.co/MU5ptwL8Eo
#
# No cars, except on special occasions. No flights, except when allowed. You and your children are being reduced to y… https://t.co/McEsJUQTH4
#
# It's going to be nothing less than always less for you, peasant: for the good of the planet. Enforced by your bette… https://t.co/4bNNA81IHG
#
# https://t.co/2GsuxY0XMs https://t.co/MDUXyrXDVR
#
# Those of you who think concern about the globalist agenda behind 15 minute cities is misplaced should read the sour… https://t.co/yN6dyZYmO3
#
# China is home to 16 of the 20 regions of the world most vulnerable to climate change, according to data.
#
# The stat… https://t.co/1C3Yti3w5Z
#
# 🐍📰 Primer on Jinja Templating — https://t.co/DvTdHfnQQY
# #python https://t.co/zIgsTfw3ZX
#
# Get happy with immensely entertaining Black films, from Girls Trip to House Party to Hidden Figures and more! https://t.co/BPjRzQBKmh
#
# Always: compared to what? And pristine nature is not an appropriate comparison. https://t.co/MtF09pwkP7

# %%
tweets = api.search_tweets(
    q="#covid19",
    count=10
)
for tweet in tweets:
    print(tweet.text + "\n")
# Out:
# RT @RWittenbrink: Auf der Jagd nach verborgenen Erregern bei #LongCovid und #MECFS - Teil 1
#
# Amy Proal ist die dynamische Mitbegründerin v…
#
# RT @delcyrodriguezv: 1/4 La Comisión Presidencial para la Prevención, Atención y Control de la #COVID19 informa al pueblo de Venezuela que…
#
# Stay up to date with the latest in #COVID19 and Cancer with our online resource that brings together COVID-19 relat… https://t.co/jXtiKMK457
#
# RT @GabrielScally: COVID-19 vaccine available for all children over 6 months from Monday in Ireland. Good news today for children and paren…
#
# RT @delcyrodriguezv: 1/4 La Comisión Presidencial para la Prevención, Atención y Control de la #COVID19 informa al pueblo de Venezuela que…
#
# RT @FauziahKian: Due to #COVID19 aka #Coronavirus Ill be sending the first 900 people to like &amp; retweet this $300 -$1500 through CashApp
#
# RT @Araguaney_SRI: #TipsDePrevencion a la #COVID19 ¿Cuántos días duran los síntomas de Ómicron? "La clave en la lucha contra el coronavirus…
#
# RT @Incorrectibles: 🗣️@LMucchielli : "Le gouvernement a cherché à paralyser la médecine de ville ! Il y a eu, en France, et c'est inédit da…
#
# RT @rcvtac: ICYMI: New Location Alert: Pembroke Clinical Assessment Centre has moved: Carefor Civic Complex, 425 Cecelia St., Pembroke!
# He…
#
# RT @CDILaA: #TipsDePrevencion a la #COVID19 ¿Por que Ómicron es la variante mas contagiosa? "La clave en la lucha contra el coronavirus es…

# %%
for key in tweets[0]._json.keys():
    print(key)
# Out:
# created_at
# id
# id_str
# text
# truncated
# entities
# metadata
# source
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang

# %%
for key in tweets[0].user._json.keys():
    print(key)
# Out:
# id
# id_str
# name
# screen_name
# location
# description
# url
# entities
# protected
# followers_count
# friends_count
# listed_count
# created_at
# favourites_count
# utc_offset
# time_zone
# geo_enabled
# verified
# statuses_count
# lang
# contributors_enabled
# is_translator
# is_translation_enabled
# profile_background_color
# profile_background_image_url
# profile_background_image_url_https
# profile_background_tile
# profile_image_url
# profile_image_url_https
# profile_banner_url
# profile_link_color
# profile_sidebar_border_color
# profile_sidebar_fill_color
# profile_text_color
# profile_use_background_image
# has_extended_profile
# default_profile
# default_profile_image
# following
# follow_request_sent
# notifications
# translator_type
# withheld_in_countries

# %%
for tweet in tweepy.Cursor(api.search_tweets, q="#covid19", count=5).items(20):
    print(tweet.text)
# Out:
# RT @RWittenbrink: Auf der Jagd nach verborgenen Erregern bei #LongCovid und #MECFS - Teil 1
#
# Amy Proal ist die dynamische Mitbegründerin v…
# RT @delcyrodriguezv: 1/4 La Comisión Presidencial para la Prevención, Atención y Control de la #COVID19 informa al pueblo de Venezuela que…
# Stay up to date with the latest in #COVID19 and Cancer with our online resource that brings together COVID-19 relat… https://t.co/jXtiKMK457
# RT @GabrielScally: COVID-19 vaccine available for all children over 6 months from Monday in Ireland. Good news today for children and paren…
# RT @delcyrodriguezv: 1/4 La Comisión Presidencial para la Prevención, Atención y Control de la #COVID19 informa al pueblo de Venezuela que…
# RT @FauziahKian: Due to #COVID19 aka #Coronavirus Ill be sending the first 900 people to like &amp; retweet this $300 -$1500 through CashApp
# RT @Araguaney_SRI: #TipsDePrevencion a la #COVID19 ¿Cuántos días duran los síntomas de Ómicron? "La clave en la lucha contra el coronavirus…
# RT @Incorrectibles: 🗣️@LMucchielli : "Le gouvernement a cherché à paralyser la médecine de ville ! Il y a eu, en France, et c'est inédit da…
# RT @rcvtac: ICYMI: New Location Alert: Pembroke Clinical Assessment Centre has moved: Carefor Civic Complex, 425 Cecelia St., Pembroke!
# He…
# RT @CDILaA: #TipsDePrevencion a la #COVID19 ¿Por que Ómicron es la variante mas contagiosa? "La clave en la lucha contra el coronavirus es…
# RT @Araguaney_SRI: #TipsDePrevencion a la #COVID19 ¿Cuántos días duran los síntomas de Ómicron? "La clave en la lucha contra el coronavirus…
# RT @marzio2015: IVERMECTINA E COVID.
# Nuovo, ennesimo studio controllato randomizzato in doppio cieco (NON me lo ha detto mio cuggino) che d…
# RT @SpokespersonCHN: When meeting with Italian President Sergio Mattarella, Wang Yi noted, with #COVID19 under control, China's economic pr…
# RT @delcyrodriguezv: 1/4 La Comisión Presidencial para la Prevención, Atención y Control de la #COVID19 informa al pueblo de Venezuela que…
# RT @eric_diss: Voici la liste des 1'300 #EffetsSecondaires des vaccins #COVID19 d'après les propres documents de #Pfizer.
# Documents que Pf…
# RT @MINSAPCuba: Se confirman 5 nuevos casos de #COVID19, para un acumulado de 1 112 553 positivos.
#
# ➡ 22 casos activos
# ➡ 22 evolución clíni…
# RT @DrPaoloMezzana: Sono le 20 del 20 febbraio 2020, Ospedale di #Codogno, il #tampone del paziente 1, è POSITIVO. #SARSCoV2 #COVID19 #Ital…
# RT @Finanzas_Times: 🇺🇸 Estados Unidos | #EEUU | #USA | #Florida
#
# Los médicos empezarán a informar a los pacientes que se vayan a inocular l…
# RT @sedragulli19: 2019
# Stay at home #COVID19
#
# 2023
#  Leave the house #earthquake
# RT @Covid19Critical: ‘Global Perspectives: Dr. @PierreKory Shares Insights from Recent Trips to Sweden &amp; Australia’ - Join host Betsy Ashto…

# %%
tweets_data = []
for i, status in enumerate(tweepy.Cursor(api.search_tweets,label='dev_environment', q= "covid", fromDate=202111010000, toDate = 202111140000, maxResults = 100 ).items(100)):
    try:
        quoted_status = status.quoted_status
        extended_tweet = status.extended_tweet
    except:
        quoted_status = None
        extended_tweet = None
    single_tweet_data = {"status_id": status.id
                         , "user" : status.user.screen_name
                         , "text" : status.text
                         , "extended_tweet" : extended_tweet
                         , "geo" : status.geo
                         , "tweeted_at" : str(status.created_at)
                         , "is_a_retweeted_tweet" : status.retweeted
                         , "is_quote_status" : status.is_quote_status
                         , "retweet_count" : status.retweet_count
                         , "hashtags": status.entities['hashtags']
                         , "user_mentions" : status.entities['user_mentions']
                         , "users_num_followers" : status.user.followers_count
                         , "screen_name_replied_to" : status.in_reply_to_screen_name
                         , "status_replied_to_id": status.in_reply_to_status_id
                         , "tweet_place" : status.place
                         , "lang" : status.lang
                        }
    tweets_data.append(single_tweet_data)

tweets_df = pd.DataFrame(tweets_data)
# Out:
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults
# Unexpected parameter: label
# Unexpected parameter: fromDate
# Unexpected parameter: toDate
# Unexpected parameter: maxResults

# %%
tweets_df
# Out:
#               status_id             user  \
# 0   1627800000724860929     Ogbeni_Moore
# 1   1627799998313246723     SharanLouise
# 2   1627799995410944000     KapoAkatsuki
# 3   1627799994756390912  AntiWokeBritain
# 4   1627799993636597760       DoomerMavs
# ..                  ...              ...
# 95  1627799913504428033      gargol_3000
# 96  1627799913349148672       frekeesang
# 97  1627799913185808384  notonmywatchfyi
# 98  1627799912862691330            katbs
# 99  1627799912850006022  zecarlosbarbosa
#
#                                                  text extended_tweet   geo  \
# 0   RT @Guchomili: A quick reminder that under the...           None  None
# 1   RT @nycHealthy: All New Yorkers, especially th...           None  None
# 2   @abejajapon abejajapon san,\n@abejajapon\n\nGo...           None  None
# 3   RT @stkirsch: New Zealand records biggest incr...           None  None
# 4   @Cactus_Jacc @dalton_trigg Lmao there’s no way...           None  None
# ..                                                ...            ...   ...
# 95  RT @goddeketal: Hey @c_drosten, you are a labo...           None  None
# 96  RT @VictorIsrael_: Omo! So APC hoard COVID-19 ...           None  None
# 97               @BigBadDenis https://t.co/IzbSx7sFTF           None  None
# 98  RT @MoriartyLab: Canadian COVID Forecast Feb 1...           None  None
# 99  @DuarteF83636380 @goncalo_nspinto Pois não! Já...           None  None
#
#                    tweeted_at  is_a_retweeted_tweet  is_quote_status  \
# 0   2023-02-20 22:38:57+00:00                 False             True
# 1   2023-02-20 22:38:57+00:00                 False            False
# 2   2023-02-20 22:38:56+00:00                 False            False
# 3   2023-02-20 22:38:56+00:00                 False            False
# 4   2023-02-20 22:38:56+00:00                 False            False
# ..                        ...                   ...              ...
# 95  2023-02-20 22:38:37+00:00                 False            False
# 96  2023-02-20 22:38:37+00:00                 False            False
# 97  2023-02-20 22:38:37+00:00                 False            False
# 98  2023-02-20 22:38:36+00:00                 False            False
# 99  2023-02-20 22:38:36+00:00                 False            False
#
#    quoted_status  retweet_count  favorite_count hashtags  \
# 0           None              3               0       []
# 1           None             19               0       []
# 2           None              0               0       []
# 3           None            127               0       []
# 4           None              0               0       []
# ..           ...            ...             ...      ...
# 95          None            741               0       []
# 96          None           1190               0       []
# 97          None              0               0       []
# 98          None             24               0       []
# 99          None              0               0       []
#
#                                         user_mentions  users_num_followers  \
# 0   [{'screen_name': 'Guchomili', 'name': 'Mili ✞🍁...                 5777
# 1   [{'screen_name': 'nycHealthy', 'name': 'nychea...                  477
# 2   [{'screen_name': 'abejajapon', 'name': 'abejaj...                29264
# 3   [{'screen_name': 'stkirsch', 'name': 'Steve Ki...                 4340
# 4   [{'screen_name': 'Cactus_Jacc', 'name': 'Cactu...                   20
# ..                                                ...                  ...
# 95  [{'screen_name': 'goddeketal', 'name': 'Dr. Si...                   52
# 96  [{'screen_name': 'VictorIsrael_', 'name': 'Chl...                  298
# 97  [{'screen_name': 'BigBadDenis', 'name': 'Denis...                   95
# 98  [{'screen_name': 'MoriartyLab', 'name': 'Tara ...                  359
# 99  [{'screen_name': 'DuarteF83636380', 'name': 'D...                 6042
#
#    screen_name_replied_to  status_replied_to_id tweet_place lang
# 0                    None                   NaN        None   en
# 1                    None                   NaN        None   en
# 2              abejajapon          1.620052e+18        None   en
# 3                    None                   NaN        None   en
# 4             Cactus_Jacc          1.627799e+18        None   en
# ..                    ...                   ...         ...  ...
# 95                   None                   NaN        None   en
# 96                   None                   NaN        None   en
# 97        notonmywatchfyi          1.627800e+18        None  und
# 98                   None                   NaN        None   en
# 99        DuarteF83636380          1.627796e+18        None   pt
#
# [100 rows x 18 columns]

# %%
tweets=[]
for tweet in api.search_tweets(q='covid', lang="en", count=10, tweet_mode='extended'):
    try:
       tweets.append(tweet.retweeted_status.full_text)
    except AttributeError:  # Not a Retweet
       tweets.append(tweet.full_text)

# %%
tweets
# Out:
# ['COVID infection provides as much protection as vaccine, study finds https://t.co/ohuNuv8BWA https://t.co/flPBLhTnMb',
#  '@senorhettler The public has not been educated on what Covid 19 will do and can do to you. I had stopped masking. Then I read a bit about long Covid. Scared the hell out of me! Now, N95s, avoiding gatherings. Protect each other!',
#  'So Pfizer has created another gem. Paxlovid, an oral treatment for Covid that hasn’t been approved, but authorized for emergency use until the emergency pandemic declaration is terminated. \n\nListen to the side effects and determine if you even would consider this shit. https://t.co/GdNoCKYsJ5',
#  'If the US response to COVID was "literally doing nothing", then I shudder to think of what "doing something" looks like to Rupa. https://t.co/eZMUFuTm5x',
#  'My man I don tire. \n\nThey increased electricity tariff by 250%\n\nHoard pallatives during covid\n\nEndsars; youths were killed \n\nASUU had a long haul (2 times) and no one said a thing. \n\nAnd so on https://t.co/mln4dp03rk',
#  'Another E Street Band member has COVID\n\nJake Clemons had the night off due to COVID from the Bruce Springsteen and E Street Band show on Thursday, Feb. 16, at the Moody Center in Austin, Texas. https://t.co/QMZ3bqg5Kl',
#  "While over 1.1 million Americans died from COVID, 10 pharmaceutical CEOs are in line to receive $1.6 billion in golden parachutes including:\n\n$926 million for Moderna's CEO\n$130 million for Regeneron's CEO\n$113 million for Pfizer's CEO\n$91 million for Eli Lilly's CEO\n\nOutrageous.",
#  'Something not enough ppl talk about: RIKERS’ ONLY REASON FOR EXISTENCE IS TO ENSURE PPL GET TO COURT.\n\nSince @NYCMayor and @DOCCommish took over, the rate of getting ppl to court (which was steady even during COVID at over 94%) plummeted to just over 70%.\n\nhttps://t.co/IVNassLmSE',
#  'Odds of your child getting myocarditis:\nbefore Covid vaccine: 1 in 250,000 \nafter Covid vaccine:1 in 40\n\nDr. McCullough \n\n https://t.co/sS2ufdJgFY',
#  '"The Trials Should Have Been Halted": Rate Of \'Serious Adverse Events\' Closely Tracks Spike In Post-Vax Disabilities | ZeroHedge https://t.co/piuM9c4DBq']
